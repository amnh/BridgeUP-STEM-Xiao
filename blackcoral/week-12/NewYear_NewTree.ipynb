# %% [markdown]
# # Week 10-12: TREES
#
# ### I've kept you on your toes long enough!

# %% [markdown]
# The moment we've all been waiting for! You've spent the past three months wrangling sequence data; now, it's time to turn that data into trees.
#
# Recall your distance matrix function, which returned a numpy array with similarity scores for all six of our corals. Copy that matrix into a txt file, like so:
#
# coral_1    0 0.14 0.12 0.15 0.14 0.14 <br>
# coral_2    0.14 0 0.12 0.15 0.14 0.14 <br>
# coral_3    0.12 0.15 0 0.12 0.15 0.12 <br>
# coral_4    0.12 0.14 0.12 0 0.14 0.12 <br>
# coral_5    0.12 0.14 0.12 0.14 0 0.12 <br>
# coral_6    0.12 0.15 0.12 0.15 0.12 0 <br>
#
# Make sure you have a carriage return at the end of each line, and separate each number/word on the same line with a space. __Though you can't see it in Jupyter notebook, there should be four spaces between the organism name and the first difference score on each line__. Note: as a good sanity check, locate the 0s in your matrix -- are they on the diagonal? (Why does this make sense?)

# %% [markdown]
# ### Tree-search!
#
# Spend some time researching one of the three methods for drawing trees that we'll be discussing: maximum likelihood, maximum parsimony, and neighbor-joining. You'll be teaching the rest of the group about the method that you researched.

# %% [markdown]
# ### Tree-building begins
#
# Download [__Phylip__](http://evolution.genetics.washington.edu/phylip/getme-new1.html): remember to download the Mac OS X zip archive.

# %% [markdown]
# Once you've downloaded and installed, take a wander through the documentation, located in the __doc__ file in __phylip-3.695__. How would you go about running a neighbor-joining tree from a distance matrix? How would you go about running a Fitch tree? Where should you put your data files? Jot your thoughts below:
#
# #<br>
# #<br>
# #<br>

# %% [markdown]
# Once you've read through the documentation, you and your partner can begin tree-building! Drop your data file (should be saved as a .txt; if TextEdit wants to save as an RTF instead, do Ctrl-Shift-T to save as a txt file) into your __phylip-3.695__ directory and click on the tree-building model (fitch, kitsch, or neighbor) of your choice in the exe folder. What happens next?

# %% [markdown]
# ![input_prompt.png](attachment:input_prompt.png)

# %% [markdown]
# Give the command line an __absolute path__ to the folder where you've stored your data file (from your distance matrix function!). You can drag and drop the file onto the Terminal window, which will autofill the path for you. Note that if you do so, you must __delete the space at the end of the path (as shown above).__ If you don't, Terminal will interpret the space as a character in your file name and throw a 'file not found' error.

# %% [markdown]
# Once you've designated your input file, you need to tell Phylip where you want to store your output file, and what to call it. Again, you'll give Phylip a path to a directory and the name of your presumptive output file (it doesn't need to exist at this moment -- Phylip will create it and name it!). If you don't, the program will automatically search for a file called 'outfile.txt'. __Note: in the screenshots below, I've submitted two different input files to Phylip -- it doesn't matter where you keep your input file (though I'd recommend that you keep it in Phylip's folders), so long as you give the program a complete path to it.__

# %% [markdown]
# ![output_prompt.png](attachment:output_prompt.png)

# %% [markdown]
# ![output_path.png](attachment:output_path.png)

# %% [markdown]
# If all goes well, you should be able to locate the file you've designated for your output. Behold the tree you've just constructed (rendered in funky little dashes and ASCII characters):

# %% [markdown]
# ![output_file.png](attachment:output_file.png)
